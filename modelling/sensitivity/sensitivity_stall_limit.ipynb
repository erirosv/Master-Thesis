# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import glob

# %%
data_list_numbers = ['15', '20', '25', '30', '35', '40', '45', '50']
data_list_name = 'stall_limit_'

# %%
dataframes = []
for number in data_list_numbers:
    file_pattern = f"../data/sensitivity/stall_limit/{data_list_name}{number}/gene_fsr_results_cv_alon.csv"
    print(file_pattern)
    matching_files = glob.glob(file_pattern)
    
    for file in matching_files:
        df = pd.read_csv(file)
        dataframes.append(df)
len(dataframes)
# Out:
# ../data/sensitivity/stall_limit/stall_limit_15/gene_fsr_results_cv_alon.csv
# ../data/sensitivity/stall_limit/stall_limit_20/gene_fsr_results_cv_alon.csv
# ../data/sensitivity/stall_limit/stall_limit_25/gene_fsr_results_cv_alon.csv
# ../data/sensitivity/stall_limit/stall_limit_30/gene_fsr_results_cv_alon.csv
# ../data/sensitivity/stall_limit/stall_limit_35/gene_fsr_results_cv_alon.csv
# ../data/sensitivity/stall_limit/stall_limit_40/gene_fsr_results_cv_alon.csv
# ../data/sensitivity/stall_limit/stall_limit_45/gene_fsr_results_cv_alon.csv
# ../data/sensitivity/stall_limit/stall_limit_50/gene_fsr_results_cv_alon.csv
# 8

# %%
df_1 = dataframes[0]
df_2 = dataframes[1]
df_3 = dataframes[2]
df_4 = dataframes[3]
df_5 = dataframes[4]
df_6 = dataframes[5]
df_7 = dataframes[6]
df_8 = dataframes[7]

# %%
wrapper_names = set(df_1['_wrapper'])

# %%
# Splitting data in separate variables
df_1_DT = df_1.loc[df_1['_wrapper'] == 'DT', 'cv_SPFSR']
df_1_KNN = df_1.loc[df_1['_wrapper'] == 'KNN', 'cv_SPFSR']
df_1_NB = df_1.loc[df_1['_wrapper'] == 'NB', 'cv_SPFSR']
df_1_SVM = df_1.loc[df_1['_wrapper'] == 'SVM', 'cv_SPFSR']

df_2_DT = df_2.loc[df_2['_wrapper'] == 'DT', 'cv_SPFSR']
df_2_KNN = df_2.loc[df_2['_wrapper'] == 'KNN', 'cv_SPFSR']
df_2_NB = df_2.loc[df_2['_wrapper'] == 'NB', 'cv_SPFSR']
df_2_SVM = df_2.loc[df_2['_wrapper'] == 'SVM', 'cv_SPFSR']

df_3_DT = df_3.loc[df_3['_wrapper'] == 'DT', 'cv_SPFSR']
df_3_KNN = df_3.loc[df_3['_wrapper'] == 'KNN', 'cv_SPFSR']
df_3_NB = df_3.loc[df_3['_wrapper'] == 'NB', 'cv_SPFSR']
df_3_SVM = df_3.loc[df_3['_wrapper'] == 'SVM', 'cv_SPFSR']

df_4_DT = df_4.loc[df_4['_wrapper'] == 'DT', 'cv_SPFSR']
df_4_KNN = df_4.loc[df_4['_wrapper'] == 'KNN', 'cv_SPFSR']
df_4_NB = df_4.loc[df_4['_wrapper'] == 'NB', 'cv_SPFSR']
df_4_SVM = df_4.loc[df_4['_wrapper'] == 'SVM', 'cv_SPFSR']

df_5_DT = df_5.loc[df_5['_wrapper'] == 'DT', 'cv_SPFSR']
df_5_KNN = df_5.loc[df_5['_wrapper'] == 'KNN', 'cv_SPFSR']
df_5_NB = df_5.loc[df_5['_wrapper'] == 'NB', 'cv_SPFSR']
df_5_SVM = df_5.loc[df_5['_wrapper'] == 'SVM', 'cv_SPFSR']

df_6_DT = df_6.loc[df_6['_wrapper'] == 'DT', 'cv_SPFSR']
df_6_KNN = df_6.loc[df_6['_wrapper'] == 'KNN', 'cv_SPFSR']
df_6_NB = df_6.loc[df_6['_wrapper'] == 'NB', 'cv_SPFSR']
df_6_SVM = df_6.loc[df_6['_wrapper'] == 'SVM', 'cv_SPFSR']

df_7_DT = df_7.loc[df_7['_wrapper'] == 'DT', 'cv_SPFSR']
df_7_KNN = df_7.loc[df_7['_wrapper'] == 'KNN', 'cv_SPFSR']
df_7_NB = df_7.loc[df_7['_wrapper'] == 'NB', 'cv_SPFSR']
df_7_SVM = df_7.loc[df_7['_wrapper'] == 'SVM', 'cv_SPFSR']

df_8_DT = df_8.loc[df_8['_wrapper'] == 'DT', 'cv_SPFSR']
df_8_KNN = df_8.loc[df_8['_wrapper'] == 'KNN', 'cv_SPFSR']
df_8_NB = df_8.loc[df_8['_wrapper'] == 'NB', 'cv_SPFSR']
df_8_SVM = df_8.loc[df_8['_wrapper'] == 'SVM', 'cv_SPFSR']

# %%
df_DT_mean = []
df_DT_mean.append(df_1_DT.mean())
df_DT_mean.append(df_2_DT.mean())
df_DT_mean.append(df_3_DT.mean())
df_DT_mean.append(df_4_DT.mean())
df_DT_mean.append(df_5_DT.mean())
df_DT_mean.append(df_6_DT.mean())
df_DT_mean.append(df_7_DT.mean())
df_DT_mean.append(df_8_DT.mean())

df_KNN_mean = []
df_KNN_mean.append(df_1_KNN.mean())
df_KNN_mean.append(df_2_KNN.mean())
df_KNN_mean.append(df_3_KNN.mean())
df_KNN_mean.append(df_4_KNN.mean())
df_KNN_mean.append(df_5_KNN.mean())
df_KNN_mean.append(df_6_KNN.mean())
df_KNN_mean.append(df_7_KNN.mean())
df_KNN_mean.append(df_8_KNN.mean())

df_NB_mean = []
df_NB_mean.append(df_1_NB.mean())
df_NB_mean.append(df_2_NB.mean())
df_NB_mean.append(df_3_NB.mean())
df_NB_mean.append(df_4_NB.mean())
df_NB_mean.append(df_5_NB.mean())
df_NB_mean.append(df_6_NB.mean())
df_NB_mean.append(df_7_NB.mean())
df_NB_mean.append(df_8_NB.mean())

df_SVM_mean = []
df_SVM_mean.append(df_1_SVM.mean())
df_SVM_mean.append(df_2_SVM.mean())
df_SVM_mean.append(df_3_SVM.mean())
df_SVM_mean.append(df_4_SVM.mean())
df_SVM_mean.append(df_5_SVM.mean())
df_SVM_mean.append(df_6_SVM.mean())
df_SVM_mean.append(df_7_SVM.mean())
df_SVM_mean.append(df_8_SVM.mean())

# %%
x_labels = ['15', '20', '25', '30', '35', '40', '45', '50']
plt.plot(df_DT_mean, label='DT')
plt.plot(df_KNN_mean, label='KNN')
plt.plot(df_NB_mean, label='NB')
plt.plot(df_SVM_mean, label='SVM')

plt.xticks(range(len(df_DT_mean)), x_labels)
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Plot Title')
plt.legend(loc='upper left')  # Show legend

plt.show()

# %%
plt.plot(df_DT_mean)
plt.xticks(range(len(df_DT_mean)), x_labels)
plt.xlabel('Max iteration')
plt.ylabel('Mean values')
plt.title('Desicion Tree')
plt.show()

# %%
plt.plot(df_KNN_mean)
plt.xticks(range(len(df_KNN_mean)), x_labels)
plt.xlabel('Max iteration')
plt.ylabel('Mean values')
plt.title('Desicion Tree')
plt.show()

# %%
plt.plot(df_NB_mean)
plt.xticks(range(len(df_NB_mean)), x_labels)
plt.xlabel('Max iteration')
plt.ylabel('Mean values')
plt.title('Desicion Tree')
plt.show()

# %%
plt.plot(df_SVM_mean)
plt.xticks(range(len(df_SVM_mean)), x_labels)
plt.xlabel('Max iteration')
plt.ylabel('Mean values')
plt.title('Desicion Tree')
plt.show()

# %% [markdown]
# # Testing

# %%
plt.plot(df_KNN_mean)
plt.xticks(range(len(df_KNN_mean)), x_labels)
plt.xlabel('Max iteration')
plt.ylabel('Mean values')
plt.title('Desicion Tree')

plt.grid(True, linestyle='--')  # Add gridlines with dotted lines

plt.show()

# %%
plt.plot(df_KNN_mean)
plt.xticks(range(len(df_KNN_mean)), x_labels)
plt.xlabel('Max iteration')
plt.ylabel('Mean values')
plt.title('Desicion Tree')

plt.grid(True, linestyle='--')  # Add gridlines with dotted lines

# Add dotted lines from specific x and y coordinates
x_point = 2  # x-coordinate
y_point = df_KNN_mean[2]  # y-coordinate

plt.axvline(x=x_point, color='r', linestyle='--')
plt.axhline(y=y_point, color='g', linestyle='--')

plt.show()

# %%
plt.plot(df_KNN_mean)
plt.xticks(range(len(df_KNN_mean)), x_labels)
plt.xlabel('Max iteration')
plt.ylabel('Mean values')
plt.title('Decision Tree')

plt.grid(True, linestyle='--')  # Add gridlines with dotted lines

# Add dotted lines from specific x and y coordinates
x_point = 2  # x-coordinate
y_point = df_KNN_mean[2]  # y-coordinate

plt.axvline(x=x_point, color='r', linestyle='--')
plt.axhline(y=y_point, color='g', linestyle='--')

plt.text(x_point, y_point, f'({y_point:.2f})', color='black', fontsize=12, ha='center', va='bottom')

plt.show()

# %%
plt.plot(df_KNN_mean)
plt.xticks(range(len(df_KNN_mean)), x_labels)
plt.xlabel('Max iteration')
plt.ylabel('Mean values')
plt.title('Decision Tree')

#plt.grid(True, linestyle='--')  # Add gridlines with dotted lines

# Add dotted lines from specific x and y coordinates
x_point = 1  # x-coordinate
y_point = df_KNN_mean[1]  # y-coordinate

plt.axvline(x=x_point, color='r', linestyle='--')
plt.axhline(y=y_point, color='g', linestyle='--')

# Add annotation with a box and arrow
plt.annotate(f'({y_point:.3f})',
             xy=(x_point, y_point), xycoords='data',
             xytext=(30, -30), textcoords='offset points',
             arrowprops=dict(arrowstyle="->", lw=1),
             bbox=dict(boxstyle="round,pad=0.3", fc="white", ec="black", lw=1))

plt.show()
